# %%
# hier werden verschiedene Pakete geladen
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Niederschlag = pd.read_excel("0492_21_tab_Niederschlag_gn.xlsx")

# %%
#Beim einlesen der csv date den Parameter decimal verwenden um dort die Comma-Zeichen angeben
DWD_results= pd.read_csv("DWD_BL_W_NN.csv", delimiter=";", index_col=0)

# %%
DWD_results
# Out:
#                         Bundesland Windgewschindigkeit (m/s)  Tage >1mm NN  \
# 0                Baden-Württemberg                       3,2           144
# 1                           Bayern                      2,94           156
# 2           Brandenburg mit Berlin                      3,39           110
# 3                           Hessen                      3,63           131
# 4           Mecklenburg-Vorpommern                      4,31           126
# 5         Niedersachsen mit Bremen                      3,93           156
# 6              Nordrhein-Westfalen                      3,73           153
# 7                  Rheinland-Pfalz                      4,01           137
# 8                         Saarland                      4,08           130
# 9                          Sachsen                      3,94           118
# 10                  Sachsen-Anhalt                       3,9           134
# 11  Schleswig-Holstein mit Hamburg                      4,79           151
# 12                       Thüringen                      3,75           125
#
#     Tage Wind > 5.3 ms
# 0                   32
# 1                   24
# 2                   32
# 3                   48
# 4                   90
# 5                   57
# 6                   59
# 7                   78
# 8                   81
# 9                   63
# 10                  63
# 11                 123
# 12                  59

# %%
DWD_results
# Out:
#                         Bundesland Windgewschindigkeit (m/s)  Tage >1mm NN  \
# 0                Baden-Württemberg                       3,2           144
# 1                           Bayern                      2,94           156
# 2           Brandenburg mit Berlin                      3,39           110
# 3                           Hessen                      3,63           131
# 4           Mecklenburg-Vorpommern                      4,31           126
# 5         Niedersachsen mit Bremen                      3,93           156
# 6              Nordrhein-Westfalen                      3,73           153
# 7                  Rheinland-Pfalz                      4,01           137
# 8                         Saarland                      4,08           130
# 9                          Sachsen                      3,94           118
# 10                  Sachsen-Anhalt                       3,9           134
# 11  Schleswig-Holstein mit Hamburg                      4,79           151
# 12                       Thüringen                      3,75           125
#
#     Tage Wind > 5.3 ms
# 0                   32
# 1                   24
# 2                   32
# 3                   48
# 4                   90
# 5                   57
# 6                   59
# 7                   78
# 8                   81
# 9                   63
# 10                  63
# 11                 123
# 12                  59

# %%
# Windgeschwindigkeit wurde als "object" (hier als string) gespeichert. 
DWD_results.dtypes
# Out:
# Bundesland                   object
# Windgewschindigkeit (m/s)    object
# Tage >1mm NN                  int64
# Tage Wind > 5.3 ms            int64
# dtype: object

# %%
# Windgeschwindigkeit wurde als "object" (hier als string) gespeichert. 
DWD_results.dtypes
# Out:
# Bundesland                   object
# Windgewschindigkeit (m/s)    object
# Tage >1mm NN                  int64
# Tage Wind > 5.3 ms            int64
# dtype: object

# %%
Niederschlag
# Out:
#          BUNDESLAND_NAME          STATIONSNAME  STATIONS_ID  \
# 0      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 1      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 2      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 3      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 4      Baden-Württemberg  Feldberg/Schwarzwald         1346
# ...                  ...                   ...          ...
# 64281          Thüringen              Schmücke         4501
# 64282          Thüringen              Schmücke         4501
# 64283          Thüringen              Schmücke         4501
# 64284          Thüringen              Schmücke         4501
# 64285          Thüringen              Schmücke         4501
#
#        STATIONSHÖHE IN METER ÜBER NN  NÖRDLICHE GEOGRAFISCHE BREITE IN GRAD  \
# 0                             1489.6                              47.874893
# 1                             1489.6                              47.874893
# 2                             1489.6                              47.874893
# 3                             1489.6                              47.874893
# 4                             1489.6                              47.874893
# ...                              ...                                    ...
# 64281                          937.0                              50.654562
# 64282                          937.0                              50.654562
# 64283                          937.0                              50.654562
# 64284                          937.0                              50.654562
# 64285                          937.0                              50.654562
#
#        ÖSTLICHE GEOGRAFISCHE LÄNGE IN GRAD  JAHR  MONAT  TAG  \
# 0                                 8.003817  2020      1    1
# 1                                 8.003817  2020      1    2
# 2                                 8.003817  2020      1    3
# 3                                 8.003817  2020      1    4
# 4                                 8.003817  2020      1    5
# ...                                    ...   ...    ...  ...
# 64281                            10.769332  2020     12   27
# 64282                            10.769332  2020     12   28
# 64283                            10.769332  2020     12   29
# 64284                            10.769332  2020     12   30
# 64285                            10.769332  2020     12   31
#
#        TAGESSUMME DER NIEDERSCHLAGSHÖHE IN MM  Anzahl der Tage > 1,0 mm
# 0                                         0.0                         0
# 1                                         0.0                         0
# 2                                         9.1                         1
# 3                                         3.8                         1
# 4                                         0.0                         0
# ...                                       ...                       ...
# 64281                                    14.1                         1
# 64282                                     1.4                         1
# 64283                                     3.2                         1
# 64284                                     0.9                         0
# 64285                                     2.9                         1
#
# [64286 rows x 11 columns]

# %%
#Beim einlesen der csv date den Parameter decimal verwenden um dort die Comma-Zeichen angeben
Niederschlag = pd.read_csv("0492_21_tab_Niederschlag_gn.csv", delimiter=";", decimal=",")
DWD_results= pd.read_csv("DWD_BL_W_NN.csv", delimiter=";", index_col=0,decimal=",")

# %%
DWD_results
# Out:
#                         Bundesland  Windgewschindigkeit (m/s)  Tage >1mm NN  \
# 0                Baden-Württemberg                       3.20           144
# 1                           Bayern                       2.94           156
# 2           Brandenburg mit Berlin                       3.39           110
# 3                           Hessen                       3.63           131
# 4           Mecklenburg-Vorpommern                       4.31           126
# 5         Niedersachsen mit Bremen                       3.93           156
# 6              Nordrhein-Westfalen                       3.73           153
# 7                  Rheinland-Pfalz                       4.01           137
# 8                         Saarland                       4.08           130
# 9                          Sachsen                       3.94           118
# 10                  Sachsen-Anhalt                       3.90           134
# 11  Schleswig-Holstein mit Hamburg                       4.79           151
# 12                       Thüringen                       3.75           125
#
#     Tage Wind > 5.3 ms
# 0                   32
# 1                   24
# 2                   32
# 3                   48
# 4                   90
# 5                   57
# 6                   59
# 7                   78
# 8                   81
# 9                   63
# 10                  63
# 11                 123
# 12                  59

# %%
Niederschlag
# Out:
#          BUNDESLAND_NAME          STATIONSNAME  STATIONS_ID  \
# 0      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 1      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 2      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 3      Baden-Württemberg  Feldberg/Schwarzwald         1346
# 4      Baden-Württemberg  Feldberg/Schwarzwald         1346
# ...                  ...                   ...          ...
# 64281          Thüringen              Schmücke         4501
# 64282          Thüringen              Schmücke         4501
# 64283          Thüringen              Schmücke         4501
# 64284          Thüringen              Schmücke         4501
# 64285          Thüringen              Schmücke         4501
#
#        STATIONSHÖHE IN METER ÜBER NN  NÖRDLICHE GEOGRAFISCHE BREITE IN GRAD  \
# 0                             1489.6                              47.874893
# 1                             1489.6                              47.874893
# 2                             1489.6                              47.874893
# 3                             1489.6                              47.874893
# 4                             1489.6                              47.874893
# ...                              ...                                    ...
# 64281                          937.0                              50.654562
# 64282                          937.0                              50.654562
# 64283                          937.0                              50.654562
# 64284                          937.0                              50.654562
# 64285                          937.0                              50.654562
#
#        ÖSTLICHE GEOGRAFISCHE LÄNGE IN GRAD  JAHR  MONAT  TAG  \
# 0                                 8.003817  2020      1    1
# 1                                 8.003817  2020      1    2
# 2                                 8.003817  2020      1    3
# 3                                 8.003817  2020      1    4
# 4                                 8.003817  2020      1    5
# ...                                    ...   ...    ...  ...
# 64281                            10.769332  2020     12   27
# 64282                            10.769332  2020     12   28
# 64283                            10.769332  2020     12   29
# 64284                            10.769332  2020     12   30
# 64285                            10.769332  2020     12   31
#
#        TAGESSUMME DER NIEDERSCHLAGSHÖHE IN MM  Anzahl der Tage > 1,0 mm
# 0                                         0.0                         0
# 1                                         0.0                         0
# 2                                         9.1                         1
# 3                                         3.8                         1
# 4                                         0.0                         0
# ...                                       ...                       ...
# 64281                                    14.1                         1
# 64282                                     1.4                         1
# 64283                                     3.2                         1
# 64284                                     0.9                         0
# 64285                                     2.9                         1
#
# [64286 rows x 11 columns]

# %%
Alle_BL =Niederschlag.groupby(by=["BUNDESLAND_NAME", "STATIONS_ID"])
Alle_BL

# %%
Alle_BL.sum()["TAGESSUMME DER NIEDERSCHLAGSHÖHE IN MM"].hist(bins=20)
plt.title(label="Verteiliung der Summe Jährliche Niederschlag pro Station")
# Out:
# Text(0.5, 1.0, 'Verteiliung der Summe Jährliche Niederschlag pro Station')

# %%
#Renames columns 
d = {"BUNDESLAND_NAME":"Bundesland","STATIONSNAME":"Station","STATIONS_ID":"ID",
     "STATIONSHÖHE IN METER ÜBER NN":"StationsHöhe"
    ,"NÖRDLICHE GEOGRAFISCHE BREITE IN GRAD":"GeoLänge","ÖSTLICHE GEOGRAFISCHE LÄNGE IN GRAD":"GeoBreite",
     "JAHR":"Jahr","MONAT":"Monat","TAG":"Tag","TAGESSUMME DER NIEDERSCHLAGSHÖHE IN MM":"NN_mm",
     "Anzahl der Tage > 1,0 mm":"NN_1mm","TAGESMITTEL DER WINDGESCHWINDIGKEIT IN m/s":"W_ms",
     "Anzahl der Tage > 5,3 m/s":"W_5.3ms"}

Niederschlag.rename(columns= d,inplace=True)

Niederschlag
# Out:
#               Bundesland               Station    ID  StationsHöhe   GeoLänge  \
# 0      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 1      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 2      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 3      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 4      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# ...                  ...                   ...   ...           ...        ...
# 64281          Thüringen              Schmücke  4501         937.0  50.654562
# 64282          Thüringen              Schmücke  4501         937.0  50.654562
# 64283          Thüringen              Schmücke  4501         937.0  50.654562
# 64284          Thüringen              Schmücke  4501         937.0  50.654562
# 64285          Thüringen              Schmücke  4501         937.0  50.654562
#
#        GeoBreite  Jahr  Monat  Tag  NN_mm  NN_1mm
# 0       8.003817  2020      1    1    0.0       0
# 1       8.003817  2020      1    2    0.0       0
# 2       8.003817  2020      1    3    9.1       1
# 3       8.003817  2020      1    4    3.8       1
# 4       8.003817  2020      1    5    0.0       0
# ...          ...   ...    ...  ...    ...     ...
# 64281  10.769332  2020     12   27   14.1       1
# 64282  10.769332  2020     12   28    1.4       1
# 64283  10.769332  2020     12   29    3.2       1
# 64284  10.769332  2020     12   30    0.9       0
# 64285  10.769332  2020     12   31    2.9       1
#
# [64286 rows x 11 columns]

# %%
#Convert the columns Jahr, Monat and Tag to single distinguishable timestamps

Niederschlag= Niederschlag.astype({"Jahr":str,"Monat":str,"Tag":str})

Niederschlag["Datum"]=Niederschlag["Jahr"]+"-"+Niederschlag["Monat"]+"-"+ Niederschlag["Tag"]

Niederschlag["Datum"]= Niederschlag["Datum"].apply(pd.Timestamp)

#Remove no longer needed columns
Niederschlag=Niederschlag.drop(labels=["Jahr","Tag","Monat"], axis=1)
Niederschlag
# Out:
#               Bundesland               Station    ID  StationsHöhe   GeoLänge  \
# 0      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 1      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 2      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 3      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# 4      Baden-Württemberg  Feldberg/Schwarzwald  1346        1489.6  47.874893
# ...                  ...                   ...   ...           ...        ...
# 64281          Thüringen              Schmücke  4501         937.0  50.654562
# 64282          Thüringen              Schmücke  4501         937.0  50.654562
# 64283          Thüringen              Schmücke  4501         937.0  50.654562
# 64284          Thüringen              Schmücke  4501         937.0  50.654562
# 64285          Thüringen              Schmücke  4501         937.0  50.654562
#
#        GeoBreite  NN_mm  NN_1mm      Datum
# 0       8.003817    0.0       0 2020-01-01
# 1       8.003817    0.0       0 2020-01-02
# 2       8.003817    9.1       1 2020-01-03
# 3       8.003817    3.8       1 2020-01-04
# 4       8.003817    0.0       0 2020-01-05
# ...          ...    ...     ...        ...
# 64281  10.769332   14.1       1 2020-12-27
# 64282  10.769332    1.4       1 2020-12-28
# 64283  10.769332    3.2       1 2020-12-29
# 64284  10.769332    0.9       0 2020-12-30
# 64285  10.769332    2.9       1 2020-12-31
#
# [64286 rows x 9 columns]

# %%
Alle_BL =Niederschlag.groupby(by=["Bundesland", "Station"])
Alle_BL

# %%
Station = Alle_BL.sum()["NN_mm"].hist(bins=20)
plt.title(label="Verteilung der Summe Jährliche Niederschlag pro Station")
# Out:
# Text(0.5, 1.0, 'Verteilung der Summe Jährliche Niederschlag pro Station')

# %%
x= Niederschlag["Datum"]
y = Niederschlag["NN_mm"]

s= 2*y
plt.scatter(x, y, s=s,  alpha=0.5)
plt.title(label="Unübersichtlich")
# Out:
# Text(0.5, 1.0, 'Unübersichtlich')

# %%
x= Niederschlag["Datum"]
y = Niederschlag["NN_mm"]


#Große der Grafik
plt.figure(figsize=(12,8 ), dpi=80)
plt.scatter(x, y, s=y,  alpha=0.3)
plt.title("Besser dargestellt", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Besser dargestellt')
